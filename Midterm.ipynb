# %% [markdown]
# <a href="https://colab.research.google.com/github/Pornwalaifoxall/python_dataviz2024/blob/main/Midterm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Viz 2024 Exam 1

# %% [markdown]
# 1. ความแตกต่างของ ค่าเฉลี่ย ของข้อมูล Chlo_a ทุกๆ station ระหว่างปี 2018 และ ปี 2019

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file_path = '/content/drive/MyDrive/Dataviz_2024_DATA/Exam 1/test-TidyData_2024.xlsx'
TidyData = pd.read_excel(file_path)
TidyData.head()
# Out:
#        month  station  rep.    Chlo_a    Chlo_b  total_Caro  Temp.    pH  \
# 0  July_2018        1     1  0.094645  0.011954    0.026780   30.2  5.54
# 1  July_2018        2     1  0.038433  0.059019    0.021387   29.1  6.24
# 2  July_2018        3     1  0.043884  0.089415    0.023223   29.7  5.52
# 3  July_2018        4     1  0.039836  0.064552    0.016537   29.2  5.92
# 4  July_2018        5     1  0.044712  0.062424    0.022990   29.5  5.79
#
#       EC  Salinity    TDS    DO   Nitrate  Ammonium  Phosphate  No.Algal_cell  \
# 0  622.7     330.3  545.2  4.37  0.172902  0.052817   0.012748   1.635833e+05
# 1  580.7     307.0  488.2  6.55  0.154197  0.144843   0.006086   1.166667e+06
# 2  547.1     289.4  462.2  5.67  0.153097  0.154321   0.014158   2.970000e+06
# 3  473.6     249.2  397.9  0.69  0.157026  0.387408   0.056951   5.066667e+05
# 4  685.5     366.0  581.2  4.46  0.204024  0.043387   0.007239   1.265000e+06
#
#    @dropdown
# 0        NaN
# 1        NaN
# 2        NaN
# ...

# %%
# clean data
# ลบค่า null ที่มีในทุก columns
TidyData_cleaned = TidyData.dropna(how='all')
TidyData_cleaned
# Out:
#          month  station  rep.    Chlo_a    Chlo_b  total_Caro  Temp.    pH  \
# 0    July_2018        1     1  0.094645  0.011954    0.026780   30.2  5.54
# 1    July_2018        2     1  0.038433  0.059019    0.021387   29.1  6.24
# 2    July_2018        3     1  0.043884  0.089415    0.023223   29.7  5.52
# 3    July_2018        4     1  0.039836  0.064552    0.016537   29.2  5.92
# 4    July_2018        5     1  0.044712  0.062424    0.022990   29.5  5.79
# ..         ...      ...   ...       ...       ...         ...    ...   ...
# 193  July_2019        2     3  0.030521  0.015358    0.018067   31.2  7.74
# 194  July_2019        3     3  0.024081  0.020217    0.015981   29.7  7.50
# 195  July_2019        4     3  0.015525  0.009612    0.009373   31.5  7.51
# 196  July_2019        5     3  0.015180  0.011811    0.009697   28.5  7.31
# 197  July_2019        6     3  0.008556  0.010605    0.005704   31.5  7.71
#
#         EC  Salinity    TDS    DO   Nitrate  Ammonium  Phosphate  \
# ...

# %%
#ดึงปีออกจากคอลัมน์ month แล้วเพิ่มเป็นคอลัมน์ใหม่
TidyData_cleaned['year'] = TidyData['month'].str.extract(r'(\d{4})').astype(int)
TidyData_cleaned
# Out:
#          month  station  rep.    Chlo_a    Chlo_b  total_Caro  Temp.    pH  \
# 0    July_2018        1     1  0.094645  0.011954    0.026780   30.2  5.54
# 1    July_2018        2     1  0.038433  0.059019    0.021387   29.1  6.24
# 2    July_2018        3     1  0.043884  0.089415    0.023223   29.7  5.52
# 3    July_2018        4     1  0.039836  0.064552    0.016537   29.2  5.92
# 4    July_2018        5     1  0.044712  0.062424    0.022990   29.5  5.79
# ..         ...      ...   ...       ...       ...         ...    ...   ...
# 193  July_2019        2     3  0.030521  0.015358    0.018067   31.2  7.74
# 194  July_2019        3     3  0.024081  0.020217    0.015981   29.7  7.50
# 195  July_2019        4     3  0.015525  0.009612    0.009373   31.5  7.51
# 196  July_2019        5     3  0.015180  0.011811    0.009697   28.5  7.31
# 197  July_2019        6     3  0.008556  0.010605    0.005704   31.5  7.71
#
#         EC  Salinity    TDS    DO   Nitrate  Ammonium  Phosphate  \
# ...

# %%
#คำนวณค่าเฉลี่ยของ Chlo_a สำหรับแต่ละ station ในปี 2018 และ 2019
mean_chlo_a_2018 = TidyData_cleaned[TidyData_cleaned['year'] == 2018].groupby('station')['Chlo_a'].mean()
mean_chlo_a_2019 = TidyData_cleaned[TidyData_cleaned['year'] == 2019].groupby('station')['Chlo_a'].mean()

# %%
# รวมค่าเฉลี่ยเข้าด้วยกันใน DataFrame เดียวเพื่อทำการเปรียบเทียบ
mean_chlo_a_comparison = pd.DataFrame({
    'Mean Chlo_a 2018': mean_chlo_a_2018,
    'Mean Chlo_a 2019': mean_chlo_a_2019
})
# แสดงผลลัพธ์
mean_chlo_a_comparison
# เพิ่ม columns different ขึ้นมาเพื่อดูความแตกต่าง
mean_chlo_a_comparison = pd.DataFrame({
    'Difference': mean_chlo_a_2019 - mean_chlo_a_2018,
    'Mean Chlo_a 2018': mean_chlo_a_2018,
    'Mean Chlo_a 2019': mean_chlo_a_2019
})
mean_chlo_a_comparison
# Out:
#          Difference  Mean Chlo_a 2018  Mean Chlo_a 2019
# station
# 1.0       -0.034196          0.052529          0.018333
# 2.0       -0.020245          0.048112          0.027867
# 3.0       -0.030285          0.053285          0.023000
# 4.0       -0.025060          0.046794          0.021733
# 5.0       -0.023365          0.043432          0.020067
# 6.0       -0.028142          0.043809          0.015667

# %% [markdown]
# 2. สร้างตารางค่าเฉลี่ย Chlo_b ทุกๆ station ของแต่ละเดือน

# %%
#ใช้คำสั่ง group by จัดกลุ่มช้อมูลตาม station และ month และคำนวณหาค่าเฉลี่ยของ Chlo_b
mean_chlo_b_by_month_station = TidyData_cleaned.groupby(['station', 'month'])['Chlo_b'].mean().reset_index()
mean_chlo_b_by_month_station
# Out:
#     station      month    Chlo_b
# 0         1   Apr_2019  0.051381
# 1         1   Aug_2018  0.075665
# 2         1   Dec_2018  0.070061
# 3         1   Jan_2019  0.022451
# 4         1  July_2018  0.046688
# ..      ...        ...       ...
# 61        6  June_2019  0.008583
# 62        6   May_2019  0.023882
# 63        6   Nov_2018  0.073360
# 64        6   Oct_2018  0.079449
# 65        6   Sep_2018  0.061750
#
# [66 rows x 3 columns]

# %%
# ใช้ pivot เพื่อปรับรูปแบบตาราง เพื่อให้ station เป็นแถว และ month เป็น columns
mean_chlo_b_table = mean_chlo_b_by_month_station.pivot(index='station', columns='month', values='Chlo_b')
# แสดงในรูปแบบของตาราง
mean_chlo_b_table
# Out:
# month    Apr_2019  Aug_2018  Dec_2018  Jan_2019  July_2018  July_2019  \
# station
# 1        0.051381  0.075665  0.070061  0.022451   0.046688   0.014365
# 2        0.019378  0.065403  0.064375  0.014968   0.062731   0.013691
# 3        0.030775  0.065179  0.080867  0.017722   0.073561   0.017439
# 4        0.020170  0.061289  0.061951  0.012142   0.061395   0.009257
# 5        0.027015  0.060107  0.070085  0.009789   0.064623   0.011054
# 6        0.025655  0.063027  0.065663  0.013856   0.056193   0.010073
#
# month    June_2019  May_2019  Nov_2018  Oct_2018  Sep_2018
# station
# 1         0.020548  0.015949  0.075937  0.131764  0.063890
# 2         0.013194  0.028765  0.064552  0.122767  0.074578
# 3         0.013301  0.015890  0.097963  0.106404  0.076292
# 4         0.013821  0.015559  0.070605  0.090834  0.064670
# 5         0.013880  0.016623  0.063866  0.082381  0.060733
# 6         0.008583  0.023882  0.073360  0.079449  0.061750

# %% [markdown]
# # Data Viz 2024 Exam 2

# %% [markdown]
# ให้สืบหาฆาตรกร ในคดี ฆาตรกรรม (murder) ที่เกิดขึ้นในวันที่ 15 มกราคม 2018 ที่เมือง SQL City โดยเริ่มจากการตรวจสอบ ข้อมูลคดี (crime_scene_report.csv)
# ชื่อฆาตรกร

# %%
file_path = "/content/drive/MyDrive/Dataviz_2024_DATA/Exam 2"

# %%
crime_scene_report = pd.read_csv(f"{file_path}/crime_scene_report.csv")
interview = pd.read_csv(f"{file_path}/interview.csv")
person = pd.read_csv(f"{file_path}/person.csv")
drivers_license = pd.read_csv(f"{file_path}/drivers_license.csv")
facebook_event_checkin = pd.read_csv(f"{file_path}/facebook_event_checkin.csv")
income = pd.read_csv(f"{file_path}/income.csv")
get_fit_now_member = pd.read_csv(f"{file_path}/get_fit_now_member.csv")
get_fit_now_check_in = pd.read_csv(f"{file_path}/get_fit_now_check_in.csv")

# %%
# กรองข้อมูลในตาราง crime_scene_report เพื่อหาคดีฆาตกรรมที่เกิดขึ้นในวันที่ 15 มกราคม 2018 ที่เมือง SQL City
crime_scene_report =crime_scene_report[(crime_scene_report['city'] == 'SQL City') &
 (crime_scene_report['date'] == 20180115)
& (crime_scene_report['type'] == 'murder')]
crime_scene_report
# ข้อมูลที่ได้จาก crime_scene_report จะเป็นจุดเริ่มต้นในการสืบหาฆาตกรต่อไป
# Out:
#           date    type  \
# 1227  20180115  murder
#
#                                                                                                                                                                                     description  \
# 1227  Security footage shows that there were 2 witnesses. The first witness lives at the last house on "Northwestern Dr". The second witness, named Annabel, lives somewhere on "Franklin Ave".
#
#           city
# 1227  SQL City

# %%
# โชว์ข้อมูลใน columns description ให้ครบ

pd.set_option('display.max_colwidth', None)  # or a large number
crime_scene_report
# Out:
#           date    type  \
# 1227  20180115  murder
#
#                                                                                                                                                                                     description  \
# 1227  Security footage shows that there were 2 witnesses. The first witness lives at the last house on "Northwestern Dr". The second witness, named Annabel, lives somewhere on "Franklin Ave".
#
#           city
# 1227  SQL City

# %%
# ดึงข้อมูลของ Annabel Miller จากตาราง person และเก็บข้อมูลที่พบในตัวแปร person_1
person_1 = person[(person['name'] == 'Annabel Miller')]
person_1
# Out:
#         id            name  license_id  address_number address_street_name  \
# 665  16371  Annabel Miller      490173             103        Franklin Ave
#
#            ssn
# 665  318771143

# %%
# การกรองข้อมูลจากตาราง person เพื่อหาบุคคลที่อาศัยอยู่บนถนน Northwestern Dr
person_northwestern = person[person['address_street_name'] == 'Northwestern Dr']
person_northwestern
# Out:
#          id                  name  license_id  address_number  \
# 2     10010             Muoi Cary      385336             741
# 282   12711        Norman Apolito      667757             599
# 499   14887        Morty Schapiro      118009            4919
# 528   15171          Weldon Penso      336999             311
# 811   17729        Lasonya Wildey      439686            3824
# 904   18376              Josh Shi      653712            1091
# 1021  19420           Cody Schiel      890431            3524
# 1338  22239         Dusty Sigafus      710517            1125
# 1426  23044          Val Portlock      924989            3143
# 1522  23960  Kristopher Lagerberg      658777            1392
# 1686  25615         Olevia Morena      388477             812
# 1812  26758      Angelena Billman      942074             629
# 1981  28360        Rashad Cascone      924517            3212
# 2131  29608       Willetta Lurvey      800568            1028
# ...

# %%
# หาพยานคนแรกอาศัยอยู่ที่บ้านหลังสุดท้ายบนถนน "Northwestern Dr"
# เรียงลำดับข้อมูลตาม address_number จากมากไปน้อย เพื่อหาบ้านหลังสุดท้าย
person_2 = person_northwestern.sort_values('address_number', ascending=False)
# เลือกข้อมูลแถวแรก ซึ่งจะเป็นบ้านหลังสุดท้าย
last_house_person_2 = person_2.iloc[0]  # เลือกแถวแรก
last_house_person_2
# Out:
# id                               14887
# name                    Morty Schapiro
# license_id                      118009
# address_number                    4919
# address_street_name    Northwestern Dr
# ssn                          111564949
# Name: 499, dtype: object

# %%
# ดึงข้อมูลการสัมภาษณ์ของ Annabel Miller จากตาราง interview
# - `.isin(person_1['id'])` คือการตรวจสอบว่า person_id ในตาราง interview ตรงกับ id ในตาราง person_1 หรือไม่ (ซึ่งเป็นข้อมูลของ Annabel Miller)
interview_1 = interview[interview['person_id'].isin(person_1['id'])]
interview_1
# จากบทสัมภาษณ์ ฉันเห็นเหตุการณ์ฆาตกรรมเกิดขึ้น และฉันจำฆาตกรได้ว่าเคยเห็นที่ยิมตอนที่ฉันไปออกกำลังกายเมื่อสัปดาห์ที่แล้วในวันที่ 9 มกราคม
# Out:
#       person_id  \
# 4989      16371
#
#                                                                                                                  transcript
# 4989  I saw the murder happen, and I recognized the killer from my gym when I was working out last week on January the 9th.

# %%
# ดึงข้อมูลการสัมภาษณ์ของพยานคนที่ 2
interview_2 = interview[interview['person_id'].isin([last_house_person_2['id']])]
interview_2
# Out:
#       person_id  \
# 4988      14887
#
#                                                                                                                                                                                                                            transcript
# 4988  I heard a gunshot and then saw a man run out. He had a "Get Fit Now Gym" bag. The membership number on the bag started with "48Z". Only gold members have those bags. The man got into a car with a plate that included "H42W".

# %%
 # ดึงข้อมูลการเช็คอินของสมาชิก Get Fit Now ในวันที่ 20180109 ซึ่งเป็นสิ่งที่ได้มาจากการสัมภาษณ์ของพยานคนที่ 2
get_fit_now_check_in_1 = get_fit_now_check_in[get_fit_now_check_in['check_in_date'] == 20180109]
get_fit_now_check_in_1
# Out:
#      membership_id  check_in_date  check_in_time  check_out_time
# 113          X0643       20180109            957            1164
# 889          UK1F2       20180109            344             518
# 1329         XTE42       20180109            486            1124
# 1446         1AE2H       20180109            461             944
# 1703         6LSTG       20180109            399             515
# 2137         7MWHJ       20180109            273             885
# 2435         GE5Q8       20180109            367             959
# 2700         48Z7A       20180109           1600            1730
# 2701         48Z55       20180109           1530            1700
# 2702         90081       20180109           1600            1700

# %%
# ดึงข้อมูลสมาชิก Get Fit Now ที่มี membership_id ตรงกับข้อมูลใน get_fit_now_check_in_1
# ซึ่งเป็นข้อมูลการเช็คอินของสมาชิกในวันที่ 20180109
get_fit_now_member_1 = get_fit_now_member[get_fit_now_member['id']
.isin(get_fit_now_check_in_1['membership_id'])]
get_fit_now_member_1
# Out:
#         id  person_id               name  membership_start_date  \
# 9    X0643      15247     Shondra Ledlow               20170521
# 70   UK1F2      28073   Zackary Cabotage               20170818
# 96   XTE42      55662     Sarita Bartosh               20170524
# 103  1AE2H      10815   Adriane Pelligra               20170816
# 119  6LSTG      83186      Burton Grippe               20170214
# 147  7MWHJ      31523  Blossom Crescenzo               20180309
# 164  GE5Q8      92736      Carmen Dimick               20170618
# 181  48Z7A      28819       Joe Germuska               20160305
# 182  48Z55      67318      Jeremy Bowers               20160101
# 183  90081      16371     Annabel Miller               20160208
#
#     membership_status
# 9              silver
# 70             silver
# 96               gold
# 103            silver
# 119              gold
# 147           regular
# 164              gold
# 181              gold
# 182              gold
# 183              gold

# %%
# ดึงข้อมูลของบุคคลที่มี id 28819 กับ 67318 จากตาราง person
# ดึงข้อมูลของผู้ต้องสงสัย 2 คนที่ได้จากการสืบสวน
person[(person['id'] == 28819) | (person['id'] == 67318)]
# Out:
#          id           name  license_id  address_number    address_street_name  \
# 2037  28819   Joe Germuska      173289             111                Fisk Rd
# 6327  67318  Jeremy Bowers      423327             530  Washington Pl, Apt 3A
#
#             ssn
# 2037  138909730
# 6327  871539279

# %%
# ดึงข้อมูลใบขับขี่ที่มี plate_number ประกอบด้วย 'H42W'
# ซึ่งได้จากการสัมภาษณ์พยานคนที่ 2 ที่เห็นรถต้องสงสัย
drivers_license_1 = drivers_license[drivers_license['plate_number'].str.contains('H42W')]
drivers_license_1
# Out:
#           id  age  height eye_color hair_color  gender plate_number  \
# 915   183779   21      65      blue     blonde  female       H42W0X
# 3529  423327   30      70     brown      brown    male       0H42W2
# 6240  664760   21      71     black      black    male       4H42WR
#
#        car_make car_model
# 915      Toyota     Prius
# 3529  Chevrolet  Spark LS
# 6240     Nissan    Altima

# %%
# ดึงข้อมูลการสัมภาษณ์ของ Jeremy Bowers จากตาราง interview
interview_Jeremy_Bowers = interview[(interview['person_id']== 	67318)]
interview_Jeremy_Bowers
# Out:
#       person_id  \
# 4990      67318
#
#                                                                                                                                                                                                                                               transcript
# 4990  I was hired by a woman with a lot of money. I don't know her name but I know she's around 5'5" (65") or 5'7" (67"). She has red hair and she drives a Tesla Model S. I know that she attended the SQL Symphony Concert 3 times in December 2017.\n

# %%
# หาคนที่ไป event_name ชื่อ SQL Symphony Concert 3 ครั้งภายในเดือน ธันวาคม 2017
facebook_event_checkin_employer = facebook_event_checkin[
    (facebook_event_checkin['event_name'] == 'SQL Symphony Concert') &
    (facebook_event_checkin['date'].between(20171201, 20171231))
]
concert_counts = facebook_event_checkin_employer.groupby('person_id').size()
frequent_attendees = concert_counts[concert_counts == 3].index.tolist()
facebook_event_checkin_3times = person[person['id'].isin(frequent_attendees)]
facebook_event_checkin_3times
# Out:
#          id              name  license_id  address_number address_street_name  \
# 1587  24556       Bryan Pardo      101191             703          Machine Ln
# 9985  99716  Miranda Priestly      202298            1883          Golden Ave
#
#             ssn
# 1587  816663882
# 9985  987756388

# %%
# ดึงข้อมูลใบขับขี่ของผู้ว่าจ้างที่มี license_id ตรงกับข้อมูลใน facebook_event_checkin_3times
# ซึ่งเป็นข้อมูลของคนที่ไปงาน SQL Symphony Concert 3 ครั้งในเดือนธันวาคม 2017
drivers_license_employer = drivers_license[drivers_license['id']
.isin(facebook_event_checkin_3times['license_id'])]
drivers_license_employer
# Out:
#           id  age  height eye_color hair_color  gender plate_number car_make  \
# 1105  202298   68      66     green        red  female       500123    Tesla
#
#      car_model
# 1105   Model S

# %%
# กรองข้อมูลของผู้ว่าจ้างเพื่อที่จะดึงข้อมูลเฉพาะแถวที่มี license_id ตรงกับ id ใน drivers_license_employer
person_employer = person[person['license_id'].isin(drivers_license_employer['id'])]
person_employer
# Out:
#          id              name  license_id  address_number address_street_name  \
# 9985  99716  Miranda Priestly      202298            1883          Golden Ave
#
#             ssn
# 9985  987756388

# %% [markdown]
# # Data Viz 2024 Exam 3

# %% [markdown]
# ให้แสดงวิธีการจัดการข้อมูลและนำเสนอจุดที่น่าสนใจในข้อมูลนี้มา 2 จุด

# %%
file_path = '/content/drive/MyDrive/Dataviz_2024_DATA/Exam 3/Data_Docter_ศ.นพ.ชวลิต.csv'
Data_Docter = pd.read_csv(file_path)

# %%
Data_Docter.head()
# Out:
#                                    name  \
# 0  ศ.นพ.ชวลิต ศูนย์มะเร็ง รพ.จุฬาลงกรณ์
# 1                        Nubeer Kithiya
# 2                       วาสนา คุ้มจิตต์
# 3                  Wansook Chompoo Ploy
# 4                           Aphit Aphit
#
#                                             comments  ยอดไลค์  จำนวนการตอบกลับ
# 0  กดที่ลิงค์นี้เพื่อเข้าไปอ่านคอมเม้นของโพสต์ครั...      456                3
# 1  เป็นมะเร็งลำไส้ใหญ่ ระยะที่ 3 ตอนอายุ 26 ค่ะ พ...     1400               70
# 2  แม่เป็นมะเร็งขั้วปอด ลามขึ้นสมองค่ะ เริ่มแรกที...      402               11
# 3  #มะเร็งปากมดลูกระยะCINlll เกือบเข้าระยะ 1 ตอนอ...     1600               44
# 4  ลูกสาวเป็นมะเร็งกระดูก Osteosarcomaช่วงเข่า อา...      480                5

# %%
# โชว์ข้อความเต็มใน column comments
pd.set_option('display.max_colwidth', None)
Data_Docter
# Out:
#                                       name  \
# 0     ศ.นพ.ชวลิต ศูนย์มะเร็ง รพ.จุฬาลงกรณ์
# 1                           Nubeer Kithiya
# 2                          วาสนา คุ้มจิตต์
# 3                     Wansook Chompoo Ploy
# 4                              Aphit Aphit
# ...                                    ...
# 1648                           Fear Q'bick
# 1649                          Toei Nittiya
# 1650                       Ouiaii Promsuan
# 1651                      Thanyalak Banboo
# 1652                         Maii Mutchima
#
# ...

# %%
# ตรวจสอบค่าที่ขาดหายไป
missing_Data_Docter = Data_Docter.isnull().sum()
missing_Data_Docter
# Out:
# name               0
# comments           0
# ยอดไลค์            0
# จำนวนการตอบกลับ    0
# dtype: int64

# %% [markdown]
# ต้องการดูความสัมพันธ์ระหว่างจำนวนยอดไลค์และจำนวนการตอบกลับและจากยอดไลค์และจำนวนการตอบกลับส่วนใหญ่คนให้ความสำคัญกับ comments ใดมากที่สุดและคิดเป็นสัดส่วนเท่าใด

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# prompt: ดูความสัมพันธ์ระหว่างยอดไลค์กับจำนวนการตอบกลับ โดยการสร้างกราฟ

plt.figure(figsize=(8, 6))
sns.scatterplot(x='ยอดไลค์', y='จำนวนการตอบกลับ', data=Data_Docter)
plt.title('Relationship between Likes and Replies')
plt.xlabel('Number of Likes')
plt.ylabel('Number of Replies')
plt.show()

# %%
# ค้นหาความคิดเห็นที่มียอดไลค์สูงสุด
most_liked_comment = Data_Docter.loc[Data_Docter['ยอดไลค์'].idxmax()]

# คำนวณสัดส่วนของยอดไลค์ที่ได้รับสูงสุด
total_likes = Data_Docter['ยอดไลค์'].sum()
most_liked_comment_ratio = (most_liked_comment['ยอดไลค์'] / total_likes) * 100

# %%
# แสดงผลลัพธ์
most_liked_comment
# Out:
# name                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Wansook Chompoo Ploy
# ...

# %%
# แสดงผลลัพธ์คิดเป็นสัดส่วนกี่เปอร์เซ็นต์
most_liked_comment_ratio
# Out:
# 14.2793395805444

# %%
# ค้นหา comments ที่มีจำนวนการตอบกลับสูงสุด
most_replied_comment = Data_Docter.loc[Data_Docter['จำนวนการตอบกลับ'].idxmax()]

# คำนวณสัดส่วนของการตอบกลับที่ได้รับสูงสุด
total_replies = Data_Docter['จำนวนการตอบกลับ'].sum()
most_replied_comment_ratio = (most_replied_comment['จำนวนการตอบกลับ'] / total_replies) * 100

# %%
# แสดงผลลัพธ์คิดเป็นสัดส่วนกี่เปอร์เซ็นต์
most_replied_comment
# Out:
# name                                                                                                                                                                                                                                   Nubeer Kithiya
# comments           เป็นมะเร็งลำไส้ใหญ่ ระยะที่ 3 ตอนอายุ 26 ค่ะ พฤติกรรมที่คิดว่ามีปัญหาคือ เลือกห้องน้ำที่จะอึ ถ้าไม่ใช่บ้าน หรือที่คุ้นเคย จะไม่ยอมถ่ายเลย จะอั้นไว้ ส่วนอาหารการกิน เราก็กินปกติ แบบคนทั่วไป ตามสั่ง ส้มตำ หมูทะ ชาบูบ้างตามโอกาส
# ยอดไลค์                                                                                                                                                                                                                                          1400
# จำนวนการตอบกลับ                                                                                                                                                                                                                                    70
# ...

# %%
most_replied_comment_ratio
# Out:
# 7.223942208462332

# %% [markdown]
# ต้องการทราบว่ามะเร็งชนิดใดที่คนที่ให้ความสนใจน้อยที่สุด

# %%
# prompt: หาคนที่เป็นมะเร็งทั้งหมด จาก comments

# สร้าง list ของคำที่เกี่ยวข้องกับมะเร็ง
cancer_keywords = ["มะเร็ง"]

# ฟังก์ชันเพื่อตรวจสอบว่าข้อความมีคำที่เกี่ยวข้องกับมะเร็งหรือไม่
def contains_cancer_keyword(text):
  for keyword in cancer_keywords:
    if keyword in str(text):
      return True
  return False

# กรองข้อมูลเพื่อหา comments ที่มีคำที่เกี่ยวข้องกับมะเร็ง
cancer_related_comments = Data_Docter[Data_Docter['comments'].apply(contains_cancer_keyword)]

# แสดงผลลัพธ์
cancer_related_comments
# Out:
#                        name  \
# 1            Nubeer Kithiya
# 2           วาสนา คุ้มจิตต์
# 3      Wansook Chompoo Ploy
# 4               Aphit Aphit
# 5                Ize Atitya
# ...                     ...
# 1639              Amika Phs
# 1641  Woranaphatchon Phupho
# 1643        Narisa Mohthong
# 1644          Chanisara Hom
# 1646        Aummy Saenluang
#
# ...

# %%
# prompt: จาก comments หาคนที่ให้ความสนใจกับมะเร็งชนิดนั้นน้อยที่สุดโดยดูจากยอดไลค์และจำนวนการตอบกลับ
# กรองข้อมูลเพื่อหา comments ที่มีคำที่เกี่ยวข้องกับมะเร็ง
cancer_related_comments = Data_Docter[Data_Docter['comments'].apply(contains_cancer_keyword)]

# %%
# จัดกลุ่มข้อมูลตาม comments และคำนวณยอดไลค์และจำนวนการตอบกลับรวม
cancer_comments_grouped = cancer_related_comments.groupby('comments').agg({'ยอดไลค์': 'sum', 'จำนวนการตอบกลับ': 'sum'}).reset_index()

# %%
# ค้นหา comments ที่มียอดไลค์และจำนวนการตอบกลับน้อยที่สุด
least_interest_comment = cancer_comments_grouped.loc[
    (cancer_comments_grouped['ยอดไลค์'] + cancer_comments_grouped['จำนวนการตอบกลับ']).idxmin()]

# %%
# แสดงผลลัพธ์
least_interest_comment
# Out:
# comments            ตาเป็นมะเร็งตับ (ไม่กินเหล้า ไม่สูบบุหรี่) เริ่มจากปวดท้องแน่นท้องคิดว่าแค่ปวดท้องธรรมดาแต่ไม่หาย ลูกๆเลยพาหาหมอ ตรวจเจอระยะสุดท้าย อยู่ได้ 2 เดือนก็เสีย
# ยอดไลค์                                                                                                                                                                     0
# จำนวนการตอบกลับ                                                                                                                                                             0
# Name: 0, dtype: object
